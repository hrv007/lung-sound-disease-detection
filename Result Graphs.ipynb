# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_enb0 = pd.read_csv('Better Results/ENB0_History.csv', index_col = 0)
df_enb1 = pd.read_csv('Better Results/ENB1_History.csv', index_col = 0)
df_inception = pd.read_csv('Better Results/Inception_History.csv', index_col = 0)
df_xception = pd.read_csv('Better Results/Xception_History.csv', index_col = 0)
df_vgg = pd.read_csv('Better Results/VGG_History.csv', index_col = 0)
df_resnet = pd.read_csv('Better Results/ResNet_History.csv', index_col = 0)

# %%
df_enb0.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  2.162742  0.125115  2.754816      0.018382
# 1  1.685826  0.280129  2.130123      0.033088
# 2  1.320754  0.455842  1.187256      0.588235
# 3  1.104444  0.583257  0.761025      0.812500
# 4  0.951242  0.670653  0.580796      0.875000

# %%
new_df = pd.DataFrame([df_enb0['val_accuracy'], df_enb1['val_accuracy'], df_inception['val_accuracy'], df_xception['val_accuracy'], df_vgg['val_accuracy'], df_resnet['val_accuracy']])
new_df.head()
# Out:
#                     0         1         2         3         4         5   \
# val_accuracy  0.018382  0.033088  0.588235  0.812500  0.875000  0.884191
# val_accuracy  0.031250  0.055147  0.444853  0.738971  0.834559  0.869485
# val_accuracy  0.196691  0.090074  0.700368  0.829044  0.862132  0.875000
# val_accuracy  0.047794  0.454044  0.558824  0.674632  0.709559  0.713235
# val_accuracy  0.047794  0.080882  0.365809  0.095588  0.452206  0.748162
#
#                     6         7         8         9   ...        90        91  \
# val_accuracy  0.897059  0.906250  0.908088  0.911765  ...  0.996324  0.996324
# val_accuracy  0.891544  0.900735  0.920956  0.920956  ...  0.994485  0.990809
# val_accuracy  0.893382  0.887868  0.898897  0.887868  ...  0.961397  0.966912
# val_accuracy  0.738971  0.766544  0.783088  0.786765  ...  0.983456  0.983456
# val_accuracy  0.580882  0.803309  0.792279  0.808824  ...  0.904412  0.904412
#
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(df_enb0['val_accuracy'], label='EfficientNetB0')
plt.plot(df_enb1['val_accuracy'], label='EfficientNetB1')
plt.plot(df_inception['val_accuracy'], label='InceptionV3')
plt.plot(df_xception['val_accuracy'], label='Xception')
plt.plot(df_vgg['val_accuracy'], label='VGG19')
plt.plot(df_resnet['val_accuracy'], label='ResNet50')
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.gca().set_ylim(-0.1, 1.1)
plt.savefig("Better Results/Validation Comparison.png")
plt.show()

# %%
tt_enb0 = [88, 36, 35, 35, 36, 35, 36, 35, 35, 35,35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 36, 35, 35, 35, 35, 35, 35, 35, 35, 35, 36, 35, 35, 34, 34, 34, 36, 35, 35, 34, 35, 36, 35, 35, 35, 35, 35, 34, 35, 36, 35, 35, 35, 36, 35, 35, 35, 35, 36, 35, 35, 35, 35, 36, 36, 35, 35, 36, 35, 36, 35, 35, 34, 35, 35, 35, 35, 36, 35, 35, 35, 35, 35, 34, 36, 35, 36, 36, 35, 36, 35, 35, 36, 35, 37, 36, 35]
tt_enb1 = [125, 51, 52, 51, 51, 52, 51, 52, 51, 52, 52, 52, 52, 51, 51, 51, 52, 51, 51, 51, 51, 51, 51, 51, 51, 52, 51, 51, 51, 51, 52, 51, 51, 51, 51, 52, 51, 52, 51, 51, 51, 51, 52, 51, 51, 51, 52, 51, 51, 51, 51, 51, 52, 52, 51, 51, 51, 52, 51, 51, 51, 51, 51, 51, 51, 52, 52, 51, 51, 52, 51, 51, 52, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 51, 52, 51, 51, 52, 51, 52, 51, 52]
tt_inception = [84, 23, 23, 24, 24, 24, 23, 23, 23, 24, 23, 24, 23, 23, 23, 23, 24, 23, 23, 24, 23, 24, 24, 24, 23, 23, 24, 24, 23, 24, 23, 23, 24, 23, 23, 24, 24, 24, 24, 24, 23, 24, 24, 23, 23, 23, 23, 24, 24, 23, 23, 24, 23, 23, 23, 24, 24, 23, 24, 23, 23, 24, 24, 23, 24, 24, 24, 23, 24, 23, 23, 23, 23, 23, 23, 24, 23, 23, 23, 23, 23, 24, 23, 23, 24, 23, 23, 24, 23, 23, 23, 24, 23, 23, 23, 23, 23, 24, 24, 24]
tt_xception = [96, 44, 44, 44, 44, 44, 46, 46, 44, 44, 44, 44, 46, 46, 44, 46, 44, 44, 44, 46, 44, 44, 44, 46, 44, 44, 44, 44, 46, 44, 46, 46, 44, 44, 44, 44, 46, 44, 46, 44, 46, 46, 44, 46, 44, 46, 44, 44, 44, 44, 46, 44, 46, 46, 44, 46, 46, 44, 44, 44, 44, 46, 44, 46, 46, 44, 46, 44, 44, 44, 46, 46, 44, 46, 44, 44, 44, 44, 46, 44, 44, 46, 44, 44, 44, 44, 44, 44, 46, 46, 44, 46, 44, 44, 46, 46, 44, 46, 44, 44]
tt_vgg = [79, 44, 42, 44, 42, 42, 44, 42, 42, 42, 44, 42, 44, 42, 44, 42, 44, 42, 44, 42, 42, 44, 44, 42, 42, 44, 44, 42, 44, 44, 44, 42, 42, 44, 44, 44, 42, 42, 42, 42, 42, 42, 44, 42, 42, 44, 44, 44, 44, 44, 44, 42, 44, 44, 44, 44, 42, 44, 42, 42, 42, 44, 42, 44, 42, 42, 44, 42, 42, 42, 42, 42, 42, 42, 42, 44, 42, 42, 42, 44, 44, 42, 42, 44, 44, 42, 44, 44, 44, 42, 44, 44, 42, 44, 42, 42, 42, 42, 42, 44]
tt_resnet = [82, 28, 28 , 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28]

# %%
plt.figure(figsize=(8,5))
plt.plot(np.cumsum(tt_enb0), label='EfficientNetB0')
plt.plot(np.cumsum(tt_enb1), label='EfficientNetB1')
plt.plot(np.cumsum(tt_inception), label='InceptionV3')
plt.plot(np.cumsum(tt_xception), label='Xception')
plt.plot(np.cumsum(tt_vgg), label='VGG19')
plt.plot(np.cumsum(tt_resnet), label='ResNet50')
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('Training Time')
plt.legend()
# plt.gca().set_ylim(-0.1, 1.1)
plt.savefig("Better Results/Training Time.png")
plt.show()

# %%
df_enb0 = pd.read_csv('Better Results/ENB0_Inference.csv', index_col = 0)
df_enb1 = pd.read_csv('Better Results/ENB1_Inference.csv', index_col = 0)
df_inception = pd.read_csv('Better Results/Inception_Inference.csv', index_col = 0)
df_xception = pd.read_csv('Better Results/Xception_Inference.csv', index_col = 0)
df_vgg = pd.read_csv('Better Results/VGG_Inference.csv', index_col = 0)
df_resnet = pd.read_csv('Better Results/ResNet_Inference.csv', index_col = 0)

# %%
df_enb0
# Out:
#          0
# 0    85046
# 1    70156
# 2    75111
# 3    76807
# 4    75980
# ..     ...
# 59  220258
# 60  216286
# 61  367769
# 62  219623
# 63  364715
#
# [64 rows x 1 columns]

# %%
plt.figure(figsize=(8,5))
plt.plot(df_enb0, label='EfficientNetB0')
plt.plot(df_enb1, label='EfficientNetB1')
plt.plot(df_inception, label='InceptionV3')
plt.plot(df_xception, label='Xception')
plt.plot(df_vgg, label='VGG19')
plt.plot(df_resnet, label='ResNet50')
plt.grid(True)
plt.xlabel('Number of Inputs')
plt.ylabel('Inference Time (in Microseconds)')
plt.legend(loc='upper right')
plt.savefig("Better Results/Inference Time.png")
plt.show()

# %%
df_adam = pd.read_csv('Better Results/ENB0_history.csv', index_col=0)
df_sgd = pd.read_csv('Better Results/SGD_history.csv', index_col=0)
df_rms = pd.read_csv('Better Results/RMSprop_history.csv', index_col=0)

# %%
df_sgd.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  1.690656  0.326127  1.837510      0.080882
# 1  1.703815  0.331647  1.681542      0.213235
# 2  1.670213  0.330727  1.749607      0.205882
# 3  1.701745  0.321987  1.757906      0.246324
# 4  1.656446  0.344526  1.735019      0.275735

# %%
plt.figure(figsize=(8,5))
plt.plot(df_adam['val_accuracy'], label='Adam')
plt.plot(df_sgd['val_accuracy'], label='SGD')
plt.plot(df_rms['val_accuracy'], label='RMSprop')
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend(loc='best')
plt.gca().set_ylim(-0.1, 1.1)
plt.savefig("Better Results/Optimizer Comparision.png")
plt.show()

# %%
df_lr = pd.read_csv('Better Results/ENB0_history.csv', index_col=0)
df_lr1 = pd.read_csv('Better Results/LR1_history.csv', index_col=0)
df_lr2 = pd.read_csv('Better Results/LR2_history.csv', index_col=0)

# %%
plt.figure(figsize=(8,5))
plt.plot(df_lr['val_accuracy'], label='LR = 3e-6')
plt.plot(df_lr1['val_accuracy'], label='LR = 3e-4')
plt.plot(df_lr2['val_accuracy'], label='LR = 3e-8')
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend(loc='best')
plt.gca().set_ylim(-0.1, 1.1)
plt.savefig("Better Results/Learning Rate Comparision.png")
plt.show()

# %%
df_mel = pd.read_csv('Better Results/ENB0_history.csv', index_col=0)
df_mfcc = pd.read_csv('Better Results/MFCC_history.csv', index_col=0)
df_cg = pd.read_csv('Better Results/Chromagrams_history.csv', index_col=0)

# %%
plt.figure(figsize=(8,5))
plt.plot(df_mel['val_accuracy'], label='Mel Spectrograms')
plt.plot(df_mfcc['val_accuracy'], label='Mel Frequency Cepstral Coefficient')
plt.plot(df_cg['val_accuracy'], label='Chromagrams')
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend(loc='best')
plt.gca().set_ylim(-0.1, 1.1)
plt.savefig("Better Results/Preprocessing Comparision.png")
plt.show()
